# %%
import pandas as pd
import scipy
import numpy as np
import re
import nltk
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity

# %%
ratings = pd.read_csv('userDatas.csv')
movies = pd.read_csv('netflix_titles.csv')
ratings = pd.merge(movies, ratings).drop(['date_added', 'release_year', 'rating', 'duration'], axis=1)
#ratings = pd.merge(movies, ratings)
#ratings.head()

# %%
ratings['cast'] = ratings['cast'].fillna(' ')
ratings['fav_cast'] = ratings['fav_cast'].fillna(' ')
ratings['director'] = ratings['director'].fillna(' ')
ratings['country'] = ratings['country'].fillna(' ')

ratings.head(61)
# Out:
#    show_id     type                                         title  \
# 0       s1    Movie                          Dick Johnson Is Dead
# 1      s33  TV Show                                 Sex Education
# 2      s46    Movie                        My Heroes Were Cowboys
# 3      s47    Movie                                    Safe House
# 4      s83  TV Show                                       Lucifer
# ..     ...      ...                                           ...
# 56   s8153    Movie                                      Tarzan 2
# 57   s8278  TV Show                    The Devil Is a Part-Timer!
# 58   s8299    Movie                         The Final Destination
# 59   s8502    Movie                     The Secret Life of Pets 2
# 60   s8595    Movie  Tinker Bell and the Legend of the NeverBeast
#
#            director                                               cast  \
# 0   Kirsten Johnson
# 1                    Asa Butterfield, Gillian Anderson, Ncuti Gatwa...
# 2       Tyler Greco
# 3   Daniel Espinosa  Denzel Washington, Ryan Reynolds, Vera Farmiga...
# 4                    Tom Ellis, Lauren German, Kevin Alejandro, D.B...
# ..              ...                                                ...
# 56      Brian Smith  Harrison Chad, George Carlin, Brad Garrett, Ro...
# 57                   Ryota Osaka, Yoko Hikasa, Nao Toyama, Yuki Ono...
# 58   David R. Ellis  Bobby Campo, Shantel VanSanten, Nick Zano, Hal...
# 59     Chris Renaud  Patton Oswalt, Kevin Hart, Tiffany Haddish, Je...
# 60      Steve Loter  Ginnifer Goodwin, Mae Whitman, Rosario Dawson,...
#
#                                country  \
# 0                        United States
# 1                       United Kingdom
# 2
# 3   South Africa, United States, Japan
# 4                        United States
# ..                                 ...
# 56                       United States
# 57                               Japan
# 58                       United States
# 59        United States, France, Japan
# 60                       United States
#
#                                             listed_in  \
# 0                                       Documentaries
# 1   British TV Shows, International TV Shows, TV C...
# 2                                       Documentaries
# 3                                  Action & Adventure
# 4              Crime TV Shows, TV Comedies, TV Dramas
# ..                                                ...
# 56                           Children & Family Movies
# 57                                       Anime Series
# 58                                      Horror Movies
# 59                 Children & Family Movies, Comedies
# 60                           Children & Family Movies
#
#                                           description user_id  \
# 0   As her father nears the end of his life, filmm...      u5
# 1   Insecure Otis has all the answers when it come...      u9
# 2   Robin Wiltshire's painful childhood was rescue...      u5
# 3   Young CIA operative Matt Weston must get a dan...      u3
# 4   Bored with being the Lord of Hell, the devil r...      u9
# ..                                                ...     ...
# 56  How did the King of the Jungle ascend to the t...      u2
# 57  Thwarted in their attempt to take over the wor...      u4
# 58  Nick O'Bannon thinks he's cheated death when h...      u6
# 59  On a farm outside New York, Max aims to boost ...      u2
# 60  When suspicious scout fairies scheme to captur...      u2
#
#                    fav_genre  \
# 0              Documentaries
# 1                   Comedies
# 2              Documentaries
# 3         Action & Adventure
# 4                   Comedies
# ..                       ...
# 56  Children & Family Movies
# 57              Anime Series
# 58             Horror Movies
# 59  Children & Family Movies
# 60  Children & Family Movies
#
#                                              fav_cast  user_rating
# 0                                                                2
# 1                      Joel Courtney,Stephen Jennings            5
# 2                                                                5
# 3   Chris Hemsworth,Rain,Matt Damon,Jason Statham,...            3
# 4                      Joel Courtney,Stephen Jennings            5
# ..                                                ...          ...
# 56                                                               5
# 57                                                               5
# 58  Guy Pearce,Patrick Wilson,Madison Wolfe,Cassan...            3
# 59                                                               3
# 60                                                               2
#
# [61 rows x 12 columns]

# %% [markdown]
# # User - User

# %% [markdown]
# ### Genre

# %%
ratings['clean_genre'] = ratings['fav_genre'].str.lower()
ratings['clean_genre'] = ratings['clean_genre'].apply(lambda x: re.sub(' ', '', x))
ratings['clean_genre'] = ratings['clean_genre'].apply(lambda x: re.sub('\s+', ' ', x))
#ratings['clean_genre'] = ratings['clean_genre'].apply(lambda x: x.split(','))
#ratings['clean_genre'] = ratings['clean_genre'].str.split(',')
pd.set_option('display.max_rows', 100)
#ratings['clean_genre']
ratings
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                               Dick Johnson Is Dead
# 1      s33  TV Show                                      Sex Education
# 2      s46    Movie                             My Heroes Were Cowboys
# 3      s47    Movie                                         Safe House
# 4      s83  TV Show                                            Lucifer
# 5     s113    Movie                                              Worth
# 6     s132    Movie                        Blade Runner: The Final Cut
# 7     s144    Movie                                      Green Lantern
# 8     s222    Movie        Bob Ross: Happy Accidents, Betrayal & Greed
# 9     s280    Movie               Monster Hunter: Legends of the Guild
# 10    s285    Movie                                The Kissing Booth 3
# 11    s339  TV Show                             Hunter X Hunter (2011)
# 12    s438    Movie                                         Cosmic Sin
# 13    s602    Movie                                     The Karate Kid
# 14    s603    Movie                             The Karate Kid Part II
# 15    s632  TV Show                              The Seven Deadly Sins
# 16    s644    Movie                                    The Seventh Day
# 17    s701  TV Show                                 Record of Ragnarok
# 18    s701  TV Show                                 Record of Ragnarok
# 19    s722    Movie                   Rogue Warfare: Death of a Nation
# 20    s779  TV Show                                    Attack on Titan
# 21    s803    Movie                                     Ninja Assassin
# 22    s855    Movie                       Creating an Army of the Dead
# 23   s1041  TV Show                                         Durarara!!
# 24   s1046  TV Show                                    Next in Fashion
# 25   s1071    Movie                               Why Did You Kill Me?
# 26   s1090    Movie                              Two Distant Strangers
# 27   s1169  TV Show                               DOTA: Dragon's Blood
# 28   s1172    Movie                                         Seaspiracy
# 29   s1179    Movie                                          Jiu Jitsu
# 30   s1179    Movie                                          Jiu Jitsu
# 31   s1284    Movie                                      The Conjuring
# 32   s1401  TV Show                                       Bling Empire
# 33   s1436    Movie                                  Pieces of a Woman
# 34   s1485    Movie                                   Cops and Robbers
# 35   s1548  TV Show                                         Teen Mom 2
# 48  Superheroes amass to stop intergalactic sociop...      u3
# 49  A group of teenage camp counselors raises the ...      u6
# 50  This hit sitcom follows the merry misadventure...      u9
# 51  Gale has written a best-seller which has been ...      u6
# 52  Haunted by nightmares and her father's disappe...      u6
# 53  The seemingly invincible Spider-Man goes up ag...      u1
# 54  After being bitten by a radioactive spider, Br...      u1
# 55  After being shipwrecked off the African coast,...      u2
# 56  How did the King of the Jungle ascend to the t...      u2
# 57  Thwarted in their attempt to take over the wor...      u4
# 58  Nick O'Bannon thinks he's cheated death when h...      u6
# 59  On a farm outside New York, Max aims to boost ...      u2
# 60  When suspicious scout fairies scheme to captur...      u2
#
#                              fav_genre  \
# 0                        Documentaries
# 1                             Comedies
# 2                        Documentaries
# 3                   Action & Adventure
# 4                             Comedies
# 5                               Dramas
# 6                   Action & Adventure
# 7   Action & Adventure,Scifi & Fantasy
# 8                        Documentaries
# 9                   Action & Adventure
# 10                            Comedies
# 11                        Anime Series
# 12                  Action & Adventure
# 13                  Action & Adventure
# 14                  Action & Adventure
# 15                        Anime Series
# 16                       Horror Movies
# 17                        Anime Series
# 18                  Action & Adventure
# 19                  Action & Adventure
# 20                        Anime Series
# 21                  Action & Adventure
# 22                       Documentaries
# 23                        Anime Series
# 24                          Reality TV
# 25                       Documentaries
# 26                              Dramas
# 27                        Anime Series
# 28                       Documentaries
# 29                  Action & Adventure
# 30                  Action & Adventure
# 31                       Horror Movies
# 32                          Reality TV
# 33                              Dramas
# 34                              Dramas
# 35                          Reality TV
# 36                          Reality TV
# 37                              Dramas
# 38                        Anime Series
# 39                          Reality TV
# 40                          Reality TV
# 41                  Action & Adventure
# 42                          Reality TV
# 43                        Anime Series
# 44                        Anime Series
# 45                       Horror Movies
# 46                        Anime Series
# 47  Action & Adventure,Scifi & Fantasy
# 48                  Action & Adventure
# 49                       Horror Movies
# 50                            Comedies
# 51                       Horror Movies
# 52                       Horror Movies
# 53  Action & Adventure,Scifi & Fantasy
# 54  Action & Adventure,Scifi & Fantasy
# 55            Children & Family Movies
# 56            Children & Family Movies
# 57                        Anime Series
# 58                       Horror Movies
# 59            Children & Family Movies
# 60            Children & Family Movies
#
#                                              fav_cast  user_rating  \
# 0                                                                2
# 1                      Joel Courtney,Stephen Jennings            5
# 2                                                                5
# 3   Chris Hemsworth,Rain,Matt Damon,Jason Statham,...            3
# 4                      Joel Courtney,Stephen Jennings            5
# 5           Naomi Watts,Miachel Keaton,Zaria,Amy Ryan            5
# 6                              Jackie Chan,Donnie Yen            2
# 7                          Tobey Maguire,James Franco            3
# 8                                                                4
# 9                              Jackie Chan,Donnie Yen            5
# 10                     Joel Courtney,Stephen Jennings            4
# 11                                                               4
# 12  Chris Hemsworth,Rain,Matt Damon,Jason Statham,...            4
# 13                             Jackie Chan,Donnie Yen            5
# 14                             Jackie Chan,Donnie Yen            4
# 15                                                               3
# 16  Guy Pearce,Patrick Wilson,Madison Wolfe,Cassan...            4
# 17                                                               5
# 18                             Jackie Chan,Donnie Yen            5
# 19  Chris Hemsworth,Rain,Matt Damon,Jason Statham,...            5
# 20                                                               4
# 21  Chris Hemsworth,Rain,Matt Damon,Jason Statham,...            2
# 22                                                               3
# 23                                                               4
# 24                                                               5
# 25                                                               4
# 26          Naomi Watts,Miachel Keaton,Zaria,Amy Ryan            3
# 27                                                               3
# 28                                                               5
# 29  Chris Hemsworth,Rain,Matt Damon,Jason Statham,...            3
# 30                             Jackie Chan,Donnie Yen            4
# 31  Guy Pearce,Patrick Wilson,Madison Wolfe,Cassan...            5
# 32                                                               3
# 33          Naomi Watts,Miachel Keaton,Zaria,Amy Ryan            5
# 34          Naomi Watts,Miachel Keaton,Zaria,Amy Ryan            2
# 35                                                               4
# 36                                                               2
# 37          Naomi Watts,Miachel Keaton,Zaria,Amy Ryan            4
# 38                                                               2
# 39                                                               5
# 40                                                               5
# 41                             Jackie Chan,Donnie Yen            4
# 42                                                               3
# 43                                                               5
# 44                                                               2
# 45  Guy Pearce,Patrick Wilson,Madison Wolfe,Cassan...            5
# 46                                                               5
# 47                         Tobey Maguire,James Franco            5
# 48  Chris Hemsworth,Rain,Matt Damon,Jason Statham,...            5
# 49  Guy Pearce,Patrick Wilson,Madison Wolfe,Cassan...            3
# 50                     Joel Courtney,Stephen Jennings            3
# 51  Guy Pearce,Patrick Wilson,Madison Wolfe,Cassan...            5
# 52  Guy Pearce,Patrick Wilson,Madison Wolfe,Cassan...            4
# 53                         Tobey Maguire,James Franco            4
# 54                         Tobey Maguire,James Franco            5
# 55                                                               4
# 56                                                               5
# 57                                                               5
# 58  Guy Pearce,Patrick Wilson,Madison Wolfe,Cassan...            3
# 59                                                               3
# 60                                                               2
#
#                        clean_genre
# 0                    documentaries
# 1                         comedies
# 2                    documentaries
# 3                 action&adventure
# 4                         comedies
# 5                           dramas
# 6                 action&adventure
# 7   action&adventure,scifi&fantasy
# 8                    documentaries
# 9                 action&adventure
# 10                        comedies
# 11                     animeseries
# 12                action&adventure
# 13                action&adventure
# 14                action&adventure
# 15                     animeseries
# 16                    horrormovies
# 17                     animeseries
# 18                action&adventure
# 19                action&adventure
# 20                     animeseries
# 21                action&adventure
# 22                   documentaries
# 23                     animeseries
# 24                       realitytv
# 25                   documentaries
# 26                          dramas
# 27                     animeseries
# 28                   documentaries
# 29                action&adventure
# 30                action&adventure
# 31                    horrormovies
# 32                       realitytv
# 33                          dramas
# 34                          dramas
# 35                       realitytv
# 36                       realitytv
# 37                          dramas
# 38                     animeseries
# 39                       realitytv
# 40                       realitytv
# 41                action&adventure
# 42                       realitytv
# 43                     animeseries
# 44                     animeseries
# 45                    horrormovies
# 46                     animeseries
# 47  action&adventure,scifi&fantasy
# 48                action&adventure
# 49                    horrormovies
# 50                        comedies
# 51                    horrormovies
# 52                    horrormovies
# 53  action&adventure,scifi&fantasy
# 54  action&adventure,scifi&fantasy
# 55           children&familymovies
# 56           children&familymovies
# 57                     animeseries
# 58                    horrormovies
# 59           children&familymovies
# 60           children&familymovies

# %%
genre_ratings = ratings[['show_id', 'title', 'listed_in', 'user_id', 'user_rating', 'clean_genre']].copy()
genre_ratings.head(10)
# Out:
#   show_id                                        title  \
# 0      s1                         Dick Johnson Is Dead
# 1     s33                                Sex Education
# 2     s46                       My Heroes Were Cowboys
# 3     s47                                   Safe House
# 4     s83                                      Lucifer
# 5    s113                                        Worth
# 6    s132                  Blade Runner: The Final Cut
# 7    s144                                Green Lantern
# 8    s222  Bob Ross: Happy Accidents, Betrayal & Greed
# 9    s280         Monster Hunter: Legends of the Guild
#
#                                            listed_in user_id  user_rating  \
# 0                                      Documentaries      u5            2
# 1  British TV Shows, International TV Shows, TV C...      u9            5
# 2                                      Documentaries      u5            5
# 3                                 Action & Adventure      u3            3
# 4             Crime TV Shows, TV Comedies, TV Dramas      u9            5
# 5                                             Dramas     u10            5
# 6    Action & Adventure, Classic Movies, Cult Movies      u7            2
# 7               Action & Adventure, Sci-Fi & Fantasy      u1            3
# 8                                      Documentaries      u5            4
# 9  Action & Adventure, Anime Features, Children &...      u7            5
#
#                       clean_genre
# 0                   documentaries
# 1                        comedies
# 2                   documentaries
# 3                action&adventure
# 4                        comedies
# 5                          dramas
# 6                action&adventure
# 7  action&adventure,scifi&fantasy
# 8                   documentaries
# 9                action&adventure

# %%
def get_similar_genre(genre):
    #similar_genre = genre_ratings['user_id', 'clean_genre']
    temp = pd.DataFrame()
    
    #temp = genre_ratings.loc[genre_ratings['clean_genre'].isin([genre])]
    temp = genre_ratings.loc[genre_ratings['clean_genre'].str.contains(genre)]
    return temp

# %%
recc_data = get_similar_recc('action&adventure')
recc_data
# Out:
#    show_id                                 title  \
# 3      s47                            Safe House
# 6     s132           Blade Runner: The Final Cut
# 7     s144                         Green Lantern
# 9     s280  Monster Hunter: Legends of the Guild
# 12    s438                            Cosmic Sin
# 13    s602                        The Karate Kid
# 14    s603                The Karate Kid Part II
# 18    s701                    Record of Ragnarok
# 19    s722      Rogue Warfare: Death of a Nation
# 21    s803                        Ninja Assassin
# 29   s1179                             Jiu Jitsu
# 30   s1179                             Jiu Jitsu
# 41   s2221                  Ip Man 4: The Finale
# 47   s6201                Avengers: Infinity War
# 48   s6201                Avengers: Infinity War
# 53   s8068                          Spider-Man 3
# 54   s8069     Spider-Man: Into the Spider-Verse
#
#                                             listed_in user_id  user_rating  \
# 3                                  Action & Adventure      u3            3
# 6     Action & Adventure, Classic Movies, Cult Movies      u7            2
# 7                Action & Adventure, Sci-Fi & Fantasy      u1            3
# 9   Action & Adventure, Anime Features, Children &...      u7            5
# 12                                 Action & Adventure      u3            4
# 13  Action & Adventure, Children & Family Movies, ...      u7            5
# 14  Action & Adventure, Children & Family Movies, ...      u7            4
# 18               Anime Series, International TV Shows      u7            5
# 19                                 Action & Adventure      u3            5
# 21                                 Action & Adventure      u3            2
# 29                                 Action & Adventure      u3            3
# 30                                 Action & Adventure      u7            4
# 41   Action & Adventure, Dramas, International Movies      u7            4
# 47               Action & Adventure, Sci-Fi & Fantasy      u1            5
# 48               Action & Adventure, Sci-Fi & Fantasy      u3            5
# 53               Action & Adventure, Sci-Fi & Fantasy      u1            4
# 54                       Action & Adventure, Comedies      u1            5
#
#                        clean_genre
# 3                 action&adventure
# 6                 action&adventure
# 7   action&adventure,scifi&fantasy
# 9                 action&adventure
# 12                action&adventure
# 13                action&adventure
# 14                action&adventure
# 18                action&adventure
# 19                action&adventure
# 21                action&adventure
# 29                action&adventure
# 30                action&adventure
# 41                action&adventure
# 47  action&adventure,scifi&fantasy
# 48                action&adventure
# 53  action&adventure,scifi&fantasy
# 54  action&adventure,scifi&fantasy

# %%
recc_ratings = recc_data.pivot_table(index=['user_id'],columns=['title'],values='user_rating')
recc_ratings.fillna(0, inplace=True)
recc_ratings
# Out:
# title    Avengers: Infinity War  Blade Runner: The Final Cut  Cosmic Sin  \
# user_id
# u1                          5.0                          0.0         0.0
# u3                          5.0                          0.0         4.0
# u7                          0.0                          2.0         0.0
#
# title    Green Lantern  Ip Man 4: The Finale  Jiu Jitsu  \
# user_id
# u1                 3.0                   0.0        0.0
# u3                 0.0                   0.0        3.0
# u7                 0.0                   4.0        4.0
#
# title    Monster Hunter: Legends of the Guild  Ninja Assassin  \
# user_id
# u1                                        0.0             0.0
# u3                                        0.0             2.0
# u7                                        5.0             0.0
#
# title    Record of Ragnarok  Rogue Warfare: Death of a Nation  Safe House  \
# user_id
# u1                      0.0                               0.0         0.0
# u3                      0.0                               5.0         3.0
# u7                      5.0                               0.0         0.0
#
# title    Spider-Man 3  Spider-Man: Into the Spider-Verse  The Karate Kid  \
# user_id
# u1                4.0                                5.0             0.0
# u3                0.0                                0.0             0.0
# u7                0.0                                0.0             5.0
#
# title    The Karate Kid Part II
# user_id
# u1                          0.0
# u3                          0.0
# u7                          4.0

# %%
recc_columns = recc_ratings.sum(axis=0).sort_values(ascending=False)
recc_columns
# Out:
# title
# Avengers: Infinity War                  10.0
# Jiu Jitsu                                7.0
# Monster Hunter: Legends of the Guild     5.0
# Record of Ragnarok                       5.0
# Rogue Warfare: Death of a Nation         5.0
# Spider-Man: Into the Spider-Verse        5.0
# The Karate Kid                           5.0
# Cosmic Sin                               4.0
# Ip Man 4: The Finale                     4.0
# Spider-Man 3                             4.0
# The Karate Kid Part II                   4.0
# Green Lantern                            3.0
# Safe House                               3.0
# Blade Runner: The Final Cut              2.0
# Ninja Assassin                           2.0
# dtype: float64

# %%
userRatings = ratings.pivot_table(index=['user_id'],columns=['title'],values='user_rating')
print("Before: ",userRatings.shape)
#userRatings = userRatings.dropna(how='all').fillna(0)
userRatings.fillna(0, inplace=True)
print("After: ",userRatings.shape)
userRatings.head(10)

# %%
corrMatrix = userRatings.corr(method='pearson')
corrMatrix.head(10)

# %%
def standardize(row):
    new_row = (row - row.mean())/(row.max()-row.min())
    return new_row

df_temp = userRatings
df_std = df_temp.apply(standardize)

user_similarity = cosine_similarity(df_std.T)
user_similarity

# %%
from sklearn.metrics.pairwise import euclidean_distances
euclidean_dist = euclidean_distances(df_std.T)
euclidean_dist

# %%
user_similarity_df = pd.DataFrame(user_similarity,index=userRatings.columns,columns=userRatings.columns)
user_similarity_df

# %%
def get_similar_cosine(movie_name, user_rating):
    similar_score = user_similarity_df[movie_name]
    similar_score = similar_score.sort_values(ascending=False)
    #print(type(similar_ratings))
    return similar_score

# %%
new_user1 = [("ONE PIECE",5),("Sword Art Online",2),("Sex Education",4),("Hunter X Hunter (2011)",5),("Attack on Titan",4)]
similar_movies = pd.DataFrame()
for movie,rating in new_user1:
    similar_movies = similar_movies.append(get_similar_cosine(movie,rating),ignore_index = True)

for (x,_) in new_user1:
    del similar_movies[x]
    #print("drop "+ x)
similar_movies.head()

# %%
similar_movies.sum().sort_values(ascending=False).head(10)

# %%
corrMatrix = userRatings.corr(method='pearson')
corrMatrix.head(10)

# %%
def get_similar_pearson(movie_name, user_rating):
    similar_score = corrMatrix[movie_name]*(user_rating-2.5)
    similar_score = similar_score.sort_values(ascending=False)
    #print(type(similar_ratings))
    return similar_score

# %%
new_user1 = [("ONE PIECE",5),("Sword Art Online",2),("Sex Education",4),("Hunter X Hunter (2011)",5),("Attack on Titan",4)]
similar_movies = pd.DataFrame()
for movie,rating in new_user1:
    similar_movies = similar_movies.append(get_similar_pearson(movie,rating),ignore_index = True)

for (x,_) in new_user1:
    del similar_movies[x]
    #print("drop "+ x)
similar_movies.head()

# %%
similar_movies.sum().sort_values(ascending=False).head(10)

# %%
action_lover = [("Amazing Spider-Man, The (2012)",5),("Mission: Impossible III (2006)",4),("Toy Story 3 (2010)",2),("2 Fast 2 Furious (Fast and the Furious 2, The) (2003)",4)]
similar_movies = pd.DataFrame()
for movie,rating in action_lover:
    similar_movies = similar_movies.append(get_similar_pearson(movie,rating),ignore_index = True)

similar_movies.head(10)
similar_movies.sum().sort_values(ascending=False).head(20)

# %% [markdown]
# #### Evalaution Metric : RMSE ( Root Mean Squared Error )

# %%
# Function to predict ratings
def predict(ratings, similarity, type='user'):
    if type == 'user':
        mean_user_rating = ratings.mean(axis=1)
        # Use np.newaxis so that mean_user_rating has same format as ratings
        ratings_diff = (ratings - mean_user_rating[:, np.newaxis])
        pred = mean_user_rating[:, np.newaxis] + similarity.dot(ratings_diff) / np.array([np.abs(similarity).sum(axis=1)]).T
    elif type == 'item':
        pred = ratings.dot(similarity) / np.array([np.abs(similarity).sum(axis=1)])
    return pred

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# Function to calculate RMSE
def rmse(pred, actual):
    return sqrt(mean_squared_error(pred, actual))

# Predict ratings on the training data with both similarity score
user_prediction = predict(euclidean_dist, corrMatrix, type='user')
item_prediction = predict(euclidean_dist, corrMatrix, type='item')
# RMSE on the train data
print('User-based CF RMSE: ' + str(rmse(user_prediction, corrMatrix)))
print('Item-based CF RMSE: ' + str(rmse(item_prediction, corrMatrix)))
